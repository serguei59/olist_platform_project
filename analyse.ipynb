# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#import mpl_toolkits

from mpl_toolkits.basemap import Basemap
from datetime import datetime

# %%
olist_geolocation_dataset = pd.read_csv('data/olist_geolocation_dataset.csv')

# %%
olist_geolocation_dataset.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
plt.figure(figsize=(10,10))
sns.countplot(x='geolocation_state', data=olist_geolocation_dataset,
               order=olist_geolocation_dataset['geolocation_state'].value_counts().sort_values().index,
#              order=olist_geolocation_dataset['geolocation_state'].value_counts().sort_values().index) 
               palette='viridis')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 plt.figure(figsize=(10,10))
# ----> 2 sns.countplot(x='geolocation_state', data=olist_geolocation_dataset,
#       3                order=olist_geolocation_dataset['geolocation_state'].value_counts().sort_values().index,
#       4 #              order=olist_geolocation_dataset['geolocation_state'].value_counts().sort_values().index)
#       5                palette='viridis')
#
# NameError: name 'olist_geolocation_dataset' is not defined

# %% [markdown]
# L' essentiel du business est réalisé dans l' état de Sao Paulo

# %%
import sqlite3
import pandas as pd
import

# %%
connection = sqlite3.connect("olist_db.db")
df_geolocation = pd.read_sql_query("SELECT * FROM Geolocation",connection)

# %%
lat = df_geolocation['geolocation_lat']
lon = df_geolocation['geolocation_lng']

plt.figure(figsize=(15,15))

m = Basemap(llcrnrlat=-55.401805,llcrnrlon=-92.269176,urcrnrlat=13.884615,urcrnrlon=-27.581676)
m.bluemarble()
m.drawmapboundary(fill_color='#46bcec') # Make your map into any style you like
m.fillcontinents(color='#f2f2f2',lake_color='#46bcec') # Make your map into any style you like
#m.drawcoastlines()
m.drawcountries()
m.scatter(lon, lat,zorder=10,alpha=0.5,color='tomato')
